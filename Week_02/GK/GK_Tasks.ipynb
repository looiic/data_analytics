# %%
import pandas as pd
import numpy as np

# %%
bigmac_df = pd.read_csv("BigmacPrice.csv")

# %%
chicken_df = pd.read_excel("ChickenData.xlsx")

# %%
chicken_df
# Out:
#     chicken_id       weight              breed  eggs_per_year
# 0            1  2728.854920  New Hampshire Red            158
# 1            2  2323.761365         Australorp            273
# 2            3  2635.062034  New Hampshire Red            153
# 3            4  2603.985152      Plymouth Rock            268
# 4            5  3079.394487         Australorp            360
# ..         ...          ...                ...            ...
# 95          96  1959.822542      Plymouth Rock            314
# 96          97  2185.659543  New Hampshire Red            297
# 97          98  3054.760220         Australorp            156
# 98          99  2272.537250          ISA Brown            225
# 99         100  2086.848105         Australorp            213
#
# [100 rows x 4 columns]

# %%
chicken_df[["breed", "eggs_per_year"]]
# Out:
#                 breed  eggs_per_year
# 0   New Hampshire Red            158
# 1          Australorp            273
# 2   New Hampshire Red            153
# 3       Plymouth Rock            268
# 4          Australorp            360
# ..                ...            ...
# 95      Plymouth Rock            314
# 96  New Hampshire Red            297
# 97         Australorp            156
# 98          ISA Brown            225
# 99         Australorp            213
#
# [100 rows x 2 columns]

# %%
chicken_df[["breed", "eggs_per_year"]].groupby("breed").sum()
# Out:
#                    eggs_per_year
# breed
# Australorp                  5936
# Barnevelder                 5624
# ISA Brown                   3309
# New Hampshire Red           4887
# Plymouth Rock               5720

# %%
cars_df = pd.read_csv("Cars_autoscout24.csv", delimiter=";", encoding="cp1252")

# %%
cars_df["Price"] = cars_df["Price"].replace({'CHF ': '', '\.\–': '', '\'': ''}, regex=True).astype(float)

# %%
cars_df
# Out:
#       Offer_Id                                               Type    Price  \
# 0      7324420  AUDI A5 Sportback 3.0 TDI quattro S-tronic (Li...  22500.0
# 1      7512768        MERCEDES-BENZ SLK 200 7G-Tronic (Cabriolet)  23749.0
# 2      7512034  MERCEDES-BENZ C 350 Avantgarde 4Matic 7G-Troni...  18500.0
# 3      7512728  MERCEDES-BENZ A 45 AMG 4Matic Speedshift 7G-DC...  36000.0
# 4      7490242  AUDI A5 Sportback 2.0 TFSI Sport quattro S-tro...  48500.0
# ...        ...                                                ...      ...
# 3975   7137137                    FERRARI F360 Spider (Cabriolet)  58400.0
# 3976   6758841            MERCEDES-BENZ SL 500 560 SL (Cabriolet)  15900.0
# 3977   7461330          MERCEDES-BENZ CL 63 AMG 7G-Tronic (Coupé)  42000.0
# 3978   7005403                        BMW 328i Cabrio (Cabriolet)   9980.0
# 3979   7200843                  BMW 328i Cabrio Sport (Cabriolet)  13500.0
#
#           PS Init_Regist   Kilometer Fuel_Type                    Transmission
# 0     245 PS     10.2014   75'000 km    Diesel  Automatisiertes Schaltgetriebe
# 1     184 PS      6.2013   46'655 km    Benzin             Automat sequentiell
# 2     306 PS      6.2011  138'955 km    Benzin             Automat sequentiell
# 3     360 PS      8.2015   43'000 km    Benzin  Automatisiertes Schaltgetriebe
# 4     252 PS      9.2018   43'300 km    Benzin  Automatisiertes Schaltgetriebe
# ...      ...         ...         ...       ...                             ...
# 3975  400 PS      2.2002   78'000 km    Benzin  Automatisiertes Schaltgetriebe
# 3976  232 PS      1.1987  315'000 km    Benzin              Automatik-Getriebe
# 3977  525 PS      8.2007   85'000 km    Benzin             Automat sequentiell
# 3978  193 PS      8.1995  188'920 km    Benzin          Schaltgetriebe manuell
# 3979  193 PS      4.1999  134'000 km    Benzin          Schaltgetriebe manuell
#
# [3980 rows x 8 columns]

# %%
cars_df.plot.hist(column=["Price"])
# Out:
# <AxesSubplot:ylabel='Frequency'>
