# %% [markdown]
# # Neural Network with Continuous Bag of Words (CBOW)
#
# For details see: https://www.kaggle.com/code/alincijov/nlp-starter-continuous-bag-of-words-cbow

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import re
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Current working directory
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: /Users/loic/Documents/data_analytics/Week_11/Grossklasse

# %% [markdown]
# ## Data

# %% [markdown]
# ### Sentence
#
# Source: https://en.wikipedia.org/wiki/Currywurst

# %%
# Open file in read mode ('r')
with open('text.txt', 'r') as file:

    # Read the contents of the file
    sentences = file.read()

# Print the file content
print(sentences)
# Out:
# According to widespread belief, the Currywurst originated in Berlin in the post-World War II era. The restaurateur Herta Heuwer, who operated a snack stand at the corner of Kant and Kaiser-Friedrich Streets in the Charlottenburg district of Berlin since the summer of 1949, claimed to have invented the typical Currywurst sauce on September 4, 1949. She served it with grilled sausage, thus claiming to have invented the Currywurst. She later adorned her business with slogans like '1st Currywurst Grill in the World' and 'A Berlin specialty invented by us' and registered the word-image trademark 'Chillup' for her sauce in 1959 – a combination of chili and ketchup, recorded on January 21, 1959, based on the application from February 21, 1958, under the number 721319 as a trademark for 'Special Sauce' in the German Patent Office's register. Heuwer incorrectly referred to it as a 'patent.' The company Kraft (→ Mondelēz) reportedly, according to Heuwer, unsuccessfully sought her recipe and trademark rights. Throughout her life, Heuwer insisted that she had not used ketchup or a ready-made spice mix but instead mixed the sauce with tomato paste and carefully seasoned it with individual spices. In her old age, she made several television appearances and celebrated herself as the 'inventor of the Currywurst.' The German Currywurst Museum, opened in Berlin in 2009 and existing until December 2018, followed this perspective. On June 29, 2003, a memorial plaque in honor of Herta Heuwer was unveiled at the former location of her snack stand (→ Kantstraße 101; now an Asian supermarket) by the then district mayor Monika Thiemen.
#
# However, Heuwer cannot entirely claim the development of the Currywurst for herself. On the one hand, certain details of her account do not seem plausible. She wanted to remember precisely that on September 4, 1949, when she first mixed her sauce, it was raining heavily, whereas according to weather records, it was a dry day. On the other hand, the role of the butcher Max Brückner from Johanngeorgenstadt in the Ore Mountains must be considered. After the end of the war, he came to West Berlin, founded a company in Berlin-Spandau with some employees from his hometown, and had developed a self-designed process for making sausage without casing, which became known as 'Spandauer ohne Pelle' (Spandau without skin). In the early 1950s, he joined forces with Frank Friedrich, also from the Ore Mountains. The company they built, Maximilian, still exists. On older versions of the website, detailed representations of the company's history and collaboration with Herta Heuwer were found. According to this, Heuwer's 'first sauce creations' in 1949 did not lead to great success. It was only together with Frank Friedrich that she developed the final recipe, which she sold at her snack stand from then on. However, this presentation emphasizes that the Currywurst as a dish was Heuwer's invention because the idea of adding sauce was hers.
#
# 'Did Herta Heuwer invent the Currywurst? There are no doubts today that she did. The connection between casing-free 'Spandauer ohne Pelle' and her idea to combine it with her own seasoning sauce, a ketchup, is clearly her idea. For the taste success, however, in coordination with Herta Heuwer, Frank Friedrich, the present-day senior and former junior partner of the company founder Max Brückner, is responsible, who was in charge of the final taste coordination of the sausage and the sauce.'
#
# The success of Brückner's sausage without casing/skin was attributed to the post-war emergency situation. Natural casing was scarce after World War II. In sausage production, the filling (meat/fat mixture) is pressed into a casing and solidifies there to give the sausage its shape. With Brückner's manufacturing method, the sausage without casing obtained its form. The first customer was the Jankowitz family from Spandau. The 'Spandauer ohne Pelle,' along with the popular tomato sauce (following Herta Heuwer's example), was well-received. Later, when other snack sellers sold this sausage, the name 'Currywurst ohne Darm' (Currywurst without casing) prevailed.

# %% [markdown]
# ### Wordcloud

# %%
# Function to create a word cloud
def wordCloud_generator(data, title=None):
    
    wordcloud = WordCloud(height=300,
                          width=600,
                          background_color ='white',
                          min_font_size = 8
                         ).generate(" ".join(data))
    
    # Plot the WordCloud image                        
    plt.figure(figsize = (6, 4), facecolor = None) 
    plt.imshow(wordcloud, interpolation='bilinear') 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title(title,fontsize=16)
    plt.show()
    
# Create Wordcloud
wordCloud_generator(sentences, title="Word cloud")

# %% [markdown]
# ### Clean Data

# %%
# Remove special characters
sentences = re.sub('[^A-Za-z0-9]+', ' ', sentences)

# Remove 1 letter words
sentences = re.sub(r'(?:^| )\w(?:$| )', ' ', sentences).strip()

# Lower all characters
sentences = sentences.lower()

# %% [markdown]
# ## Vocabulary

# %%
# Split sentense to derive vocabulary (tokens)
words = sentences.split()
vocab = set(words)

vocab_size = len(vocab)
embed_dim = 10
context_size = 2

print(vocab)
# Out:
# {'or', 'entirely', 'after', 'great', 'this', 'seasoning', 'plausible', 'according', 'final', 'from', 'some', '2003', 'mondel', 'end', 'day', 'spandauer', 'they', 'because', 'attributed', 'became', 'us', '1958', 'individual', 'streets', 'ckner', 'without', '1959', 'followed', 'stand', 'heavily', 'german', 'as', 'register', 'mixture', 'its', 'frank', 'together', 'max', 'manufacturing', 'several', 'customer', 'throughout', 'inventor', 'herself', 'free', 'prevailed', 'skin', 'example', 'insisted', 'served', 'location', 'charge', 'still', 'claiming', 'were', 'scarce', 'between', 'shape', 'era', 'made', 'do', 'joined', 'february', 'taste', 'sausage', '2018', 'developed', 'until', 'he', 'are', 'january', 'junior', 'unsuccessfully', 'under', 'war', 'representations', 'emphasizes', 'other', 'snack', 'built', 'making', 'specialty', 'exists', 'image', 'an', 'claim', '29', 'based', 'give', 'spice', '721319', 'have', 'johanngeorgenstadt', 'on', 'process', 'with', 'company', 'production', 'whereas', 'founded', 'pelle', 'considered', 'invented', 'recorded', 'coordination', 'hers', 'west', 'name', 'age', 'must', 'post', 'butcher', 'only', 'grilled', 'by', 'sauce', 'own', 'along', 'into', 'chili', 'certain', 'slogans', 'instead', 'account', 'br', 'former', 'memorial', 'his', 'popular', 'kant', 'precisely', 'widespread', 'december', 'who', 'filling', 'thiemen', 'doubts', '21', 'pressed', 'old', '1st', 'typical', 'meat', 'at', 'perspective', 'kantstra', 'method', 'she', 'sellers', 'when', 'life', 'forces', 'ketchup', 'business', 'sought', '2009', 'mixed', 'patent', 'however', 'seem', 'and', 'mayor', 'known', 'plaque', 'creations', 'application', 'versions', 'the', 'no', 'claimed', '1950s', 'spices', 'office', '1949', 'situation', 'june', 'detailed', 'also', 'history', 'asian', 'darm', 'tomato', 'paste', 'chillup', 'one', 'unveiled', 'wanted', 'adding', 'which', 'carefully', 'combination', 'older', 'well', 'september', 'opened', 'not', 'emergency', 'maximilian', 'museum', 'lead', 'now', 'summer', 'following', 'dry', 'found', 'records', 'partner', 'founder', 'success', 'there', 'clearly', 'mix', 'heuwer', 'first', 'invention', 'for', 'referred', 'collaboration', 'role', 'rights', 'dish', 'appearances', 'ready', 'came', 'did', 'natural', 'casing', 'charlottenburg', 'used', 'celebrated', 'honor', 'obtained', 'grill', 'television', 'today', 'employees', 'recipe', 'form', 'designed', 'cannot', 'senior', 'it', 'weather', 'district', 'since', 'currywurst', 'details', 'then', 'solidifies', 'website', 'hand', 'kaiser', 'spandau', 'family', 'reportedly', 'operated', 'remember', 'ore', 'ohne', 'world', 'that', 'her', 'existing', 'belief', 'hometown', 'but', 'self', 'jankowitz', 'to', 'early', 'of', 'incorrectly', 'was', 'received', 'connection', 'berlin', 'present', 'development', 'word', 'responsible', 'supermarket', 'be', 'herta', 'idea', 'sold', 'kraft', 'had', 'corner', 'mountains', 'fat', 'ii', 'is', 'combine', 'like', 'later', 'monika', 'presentation', 'in', 'originated', '101', 'invent', 'thus', 'trademark', 'restaurateur', 'seasoned', 'registered', 'number', 'raining', 'special', 'friedrich', 'adorned'}

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Dictionaries

# %%
# Bag-of-Words
word_to_ix = {word: i for i, word in enumerate(vocab)}
ix_to_word = {i: word for i, word in enumerate(vocab)}

print(word_to_ix)
# Out:
# {'or': 0, 'entirely': 1, 'after': 2, 'great': 3, 'this': 4, 'seasoning': 5, 'plausible': 6, 'according': 7, 'final': 8, 'from': 9, 'some': 10, '2003': 11, 'mondel': 12, 'end': 13, 'day': 14, 'spandauer': 15, 'they': 16, 'because': 17, 'attributed': 18, 'became': 19, 'us': 20, '1958': 21, 'individual': 22, 'streets': 23, 'ckner': 24, 'without': 25, '1959': 26, 'followed': 27, 'stand': 28, 'heavily': 29, 'german': 30, 'as': 31, 'register': 32, 'mixture': 33, 'its': 34, 'frank': 35, 'together': 36, 'max': 37, 'manufacturing': 38, 'several': 39, 'customer': 40, 'throughout': 41, 'inventor': 42, 'herself': 43, 'free': 44, 'prevailed': 45, 'skin': 46, 'example': 47, 'insisted': 48, 'served': 49, 'location': 50, 'charge': 51, 'still': 52, 'claiming': 53, 'were': 54, 'scarce': 55, 'between': 56, 'shape': 57, 'era': 58, 'made': 59, 'do': 60, 'joined': 61, 'february': 62, 'taste': 63, 'sausage': 64, '2018': 65, 'developed': 66, 'until': 67, 'he': 68, 'are': 69, 'january': 70, 'junior': 71, 'unsuccessfully': 72, 'under': 73, 'war': 74, 'representations': 75, 'emphasizes': 76, 'other': 77, 'snack': 78, 'built': 79, 'making': 80, 'specialty': 81, 'exists': 82, 'image': 83, 'an': 84, 'claim': 85, '29': 86, 'based': 87, 'give': 88, 'spice': 89, '721319': 90, 'have': 91, 'johanngeorgenstadt': 92, 'on': 93, 'process': 94, 'with': 95, 'company': 96, 'production': 97, 'whereas': 98, 'founded': 99, 'pelle': 100, 'considered': 101, 'invented': 102, 'recorded': 103, 'coordination': 104, 'hers': 105, 'west': 106, 'name': 107, 'age': 108, 'must': 109, 'post': 110, 'butcher': 111, 'only': 112, 'grilled': 113, 'by': 114, 'sauce': 115, 'own': 116, 'along': 117, 'into': 118, 'chili': 119, 'certain': 120, 'slogans': 121, 'instead': 122, 'account': 123, 'br': 124, 'former': 125, 'memorial': 126, 'his': 127, 'popular': 128, 'kant': 129, 'precisely': 130, 'widespread': 131, 'december': 132, 'who': 133, 'filling': 134, 'thiemen': 135, 'doubts': 136, '21': 137, 'pressed': 138, 'old': 139, '1st': 140, 'typical': 141, 'meat': 142, 'at': 143, 'perspective': 144, 'kantstra': 145, 'method': 146, 'she': 147, 'sellers': 148, 'when': 149, 'life': 150, 'forces': 151, 'ketchup': 152, 'business': 153, 'sought': 154, '2009': 155, 'mixed': 156, 'patent': 157, 'however': 158, 'seem': 159, 'and': 160, 'mayor': 161, 'known': 162, 'plaque': 163, 'creations': 164, 'application': 165, 'versions': 166, 'the': 167, 'no': 168, 'claimed': 169, '1950s': 170, 'spices': 171, 'office': 172, '1949': 173, 'situation': 174, 'june': 175, 'detailed': 176, 'also': 177, 'history': 178, 'asian': 179, 'darm': 180, 'tomato': 181, 'paste': 182, 'chillup': 183, 'one': 184, 'unveiled': 185, 'wanted': 186, 'adding': 187, 'which': 188, 'carefully': 189, 'combination': 190, 'older': 191, 'well': 192, 'september': 193, 'opened': 194, 'not': 195, 'emergency': 196, 'maximilian': 197, 'museum': 198, 'lead': 199, 'now': 200, 'summer': 201, 'following': 202, 'dry': 203, 'found': 204, 'records': 205, 'partner': 206, 'founder': 207, 'success': 208, 'there': 209, 'clearly': 210, 'mix': 211, 'heuwer': 212, 'first': 213, 'invention': 214, 'for': 215, 'referred': 216, 'collaboration': 217, 'role': 218, 'rights': 219, 'dish': 220, 'appearances': 221, 'ready': 222, 'came': 223, 'did': 224, 'natural': 225, 'casing': 226, 'charlottenburg': 227, 'used': 228, 'celebrated': 229, 'honor': 230, 'obtained': 231, 'grill': 232, 'television': 233, 'today': 234, 'employees': 235, 'recipe': 236, 'form': 237, 'designed': 238, 'cannot': 239, 'senior': 240, 'it': 241, 'weather': 242, 'district': 243, 'since': 244, 'currywurst': 245, 'details': 246, 'then': 247, 'solidifies': 248, 'website': 249, 'hand': 250, 'kaiser': 251, 'spandau': 252, 'family': 253, 'reportedly': 254, 'operated': 255, 'remember': 256, 'ore': 257, 'ohne': 258, 'world': 259, 'that': 260, 'her': 261, 'existing': 262, 'belief': 263, 'hometown': 264, 'but': 265, 'self': 266, 'jankowitz': 267, 'to': 268, 'early': 269, 'of': 270, 'incorrectly': 271, 'was': 272, 'recei ...

# %% [markdown]
# ### Data bags

# %%
# Create data bags with ([context], target) as the basis for modeling
data = []

for i in range(2, len(words) - 2):
    context = [words[i - 2], words[i - 1], words[i + 1], words[i + 2]]
    target = words[i]
    data.append((context, target))

# Show first entries in 'data'
data[:20]
# Out:
# [(['according', 'to', 'belief', 'the'], 'widespread'),
#  (['to', 'widespread', 'the', 'currywurst'], 'belief'),
#  (['widespread', 'belief', 'currywurst', 'originated'], 'the'),
#  (['belief', 'the', 'originated', 'in'], 'currywurst'),
#  (['the', 'currywurst', 'in', 'berlin'], 'originated'),
#  (['currywurst', 'originated', 'berlin', 'in'], 'in'),
#  (['originated', 'in', 'in', 'the'], 'berlin'),
#  (['in', 'berlin', 'the', 'post'], 'in'),
#  (['berlin', 'in', 'post', 'world'], 'the'),
#  (['in', 'the', 'world', 'war'], 'post'),
#  (['the', 'post', 'war', 'ii'], 'world'),
#  (['post', 'world', 'ii', 'era'], 'war'),
#  (['world', 'war', 'era', 'the'], 'ii'),
#  (['war', 'ii', 'the', 'restaurateur'], 'era'),
#  (['ii', 'era', 'restaurateur', 'herta'], 'the'),
#  (['era', 'the', 'herta', 'heuwer'], 'restaurateur'),
#  (['the', 'restaurateur', 'heuwer', 'who'], 'herta'),
#  (['restaurateur', 'herta', 'who', 'operated'], 'heuwer'),
#  (['herta', 'heuwer', 'operated', 'snack'], 'who'),
#  (['heuwer', 'who', 'snack', 'stand'], 'operated')]

# %% [markdown]
# ### Word embeddings

# %%
# Create word embeddings
np.random.seed(42)
embeddings = np.random.random_sample((vocab_size, embed_dim))

# Show first embeddings
print(embeddings[0:5])

# Dimensions of np.ndarray
print('\nDimensions of np.ndarray:', embeddings.ndim)
# Out:
# [[0.37454012 0.95071431 0.73199394 0.59865848 0.15601864 0.15599452
#   0.05808361 0.86617615 0.60111501 0.70807258]
#  [0.02058449 0.96990985 0.83244264 0.21233911 0.18182497 0.18340451
#   0.30424224 0.52475643 0.43194502 0.29122914]
#  [0.61185289 0.13949386 0.29214465 0.36636184 0.45606998 0.78517596
#   0.19967378 0.51423444 0.59241457 0.04645041]
#  [0.60754485 0.17052412 0.06505159 0.94888554 0.96563203 0.80839735
#   0.30461377 0.09767211 0.68423303 0.44015249]
#  [0.12203823 0.49517691 0.03438852 0.9093204  0.25877998 0.66252228
#   0.31171108 0.52006802 0.54671028 0.18485446]]
#
# Dimensions of np.ndarray: 2

# %% [markdown]
# ### Linear Model

# %%
# Function to perform linear transformation of word embeddings
def linear(m, theta):
    w = theta

    return m.dot(w)

# %% [markdown]
# ### Log softmax + NLLLoss = Cross Entropy

# %%
# Loss function to measure the model performance during training
def log_softmax(x):
    e_x = np.exp(x - np.max(x))

    return np.log(e_x / e_x.sum())

def NLLLoss(logs, targets):
    out = logs[range(len(targets)), targets]

    return -out.sum()/len(out)

def log_softmax_crossentropy_with_logits(logits,target):
    out = np.zeros_like(logits)
    out[np.arange(len(logits)),target] = 1
    softmax = np.exp(logits) / np.exp(logits).sum(axis=-1,keepdims=True)
    
    return (- out + softmax) / logits.shape[0]

# %% [markdown]
# ### Forward function

# %%
# Function to provide a forward pass through a neural network
def forward(context_idxs, theta):
    m = embeddings[context_idxs].reshape(1, -1)
    n = linear(m, theta)
    o = log_softmax(n)
    
    return m, n, o

# %% [markdown]
# ### Backward function

# %%
# Function to provide a backward pass through a neural network
def backward(preds, theta, target_idxs):
    m, n, o = preds
    
    dlog = log_softmax_crossentropy_with_logits(n, target_idxs)
    dw = m.T.dot(dlog)
    
    return dw

# %% [markdown]
# ### Optimize function

# %%
# Function for parameter (theta) optimization
def optimize(theta, grad, lr=0.03):
    theta -= grad * lr

    return theta

# %% [markdown]
# ## Training

# %%
# Training the neural network
theta = np.random.uniform(-1, 1, (2 * context_size * embed_dim, vocab_size))

epoch_losses = {}

for epoch in range(100):

    losses =  []

    for context, target in data:
        context_idxs = np.array([word_to_ix[w] for w in context])
        preds = forward(context_idxs, theta)

        target_idxs = np.array([word_to_ix[target]])
        loss = NLLLoss(preds[-1], target_idxs)

        losses.append(loss)

        grad = backward(preds, theta, target_idxs)
        theta = optimize(theta, grad, lr=0.03)
    
    epoch_losses[epoch] = losses

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Plot loss/epoch

# %%
# Analyzing the neural network
ix = np.arange(0,100)

fig = plt.figure(figsize=(6,4))
fig.suptitle('Epoch/Losses', fontsize=14)
plt.plot(ix,[epoch_losses[i][0] for i in ix], c='orange')
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Losses', fontsize=10)
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# ### Predict next word

# %%
# Function to predict the target word
def predict(words):
    
    context_idxs = np.array([word_to_ix[w] for w in words])
    preds = forward(context_idxs, theta)
    word = ix_to_word[np.argmax(preds[-1])]
    
    return word

# Predict next word based on input words
predict(['according', 'to', 'belief', 'the'])
# Out:
# 'widespread'

# %% [markdown]
# ### Predict all targets of all data bags and show accuracy

# %%
# Calculate accuracy
def accuracy():
    wrong = 0
    for context, target in data:
        if(predict(context) != target):
            wrong += 1
            
    return (1 - (wrong / len(data)))

print(f'{accuracy():.4f}')
# Out:
# 0.8462

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 23.1.0
# Datetime: 2023-11-27 13:03:17
# Python Version: 3.9.13
# -----------------------------------
